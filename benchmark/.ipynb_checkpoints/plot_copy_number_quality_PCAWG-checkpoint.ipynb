# %%
import os 
import pandas as pd
    
import json
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob
import allel
import itertools
from matplotlib import gridspec
import matplotlib.pyplot as plt
import pickle
from statannot import add_stat_annotation
from scipy import stats
import matplotlib.cm as cm
import matplotlib

# %%
pd.options.display.max_columns=100
pd.options.display.max_rows=100
from pandas.core.common import SettingWithCopyWarning
import warnings
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %% [markdown]
# ### Read all the output

# %%
df = pd.read_csv("../escape_mutations/results/pcawg_escape_info.tsv.gz",sep="\t")

# %% [markdown]
# ### Plot copy number integer

# %%
def plot_comparison_ploidy(df):
    lim=6
    for allele in ["HLA-A","HLA-B","HLA-C"]:
        x=np.array([np.nanmin([x,lim]) for x in df[f"ploidy_minor_{allele}"].values ])
        y=np.array([np.nanmin([x,lim]) for x in df[f"ploidy_major_{allele}"].values ])
        fig,ax = plt.subplots(figsize=(5,5))
        sns.heatmap(pd.crosstab(x,y,).replace(0, np.nan),cmap="Blues",annot=True,ax=ax,cbar=False,fmt='g',vmin=1,linewidths=1.)
        ax.set_xlabel("Major allele Copy Number")
        ax.set_ylabel("Minor allele Copy Number")
        ax.set_yticklabels(ax.get_yticklabels(),rotation=0)
        ax.set_xticklabels(ax.get_xticklabels()[:-1]+[">=6"],rotation=0)
        ax.set_title(allele)
plot_comparison_ploidy(df)

# %% [markdown]
# ### Plot raw copy number

# %% [markdown]
# ##### Per allele

# %%
for allele,color in zip(["A","B","C"],["#760b23ff","#2d1a67ff","#063b07ff"]):
    fig,ax = plt.subplots(figsize=(5,5))
    ax.scatter(df[allele+"1_CN"],df[allele+"2_CN"],alpha=0.1,color=color,s=15)
    
    ax.set_title("HLA-A/B/C",fontsize=12)
    #sns.kdeplot(df[allele+"1_CN"],df[allele+"2_CN"],shade=True,palette=cm.Greys,cut=0,shade_lowest=False,bw=0.1           )
    ax.set_ylim(-0.5,6)
    ax.set_xlim(-0.5,6)
    ax.set_ylabel("Copy Number first allele HLA allele",fontsize=12)
    ax.set_xlabel("Copy Number second allele  HLA allele",fontsize=12)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    ax.tick_params(axis='both', which='major', labelsize=12)
    plt.savefig(f'plots/PCAWG_CN_{allele}.pdf', dpi=800,bbox_inches="tight")

# %%
fig,ax = plt.subplots(figsize=(5,5))
for allele,color in zip(["A","B","C"],["#1b9e77","#d95f02","#7570b3"]):
    
    ax.scatter(df[allele+"1_CN"],df[allele+"2_CN"],alpha=0.1,color="#ef8a62",s=15)
    
    ax.set_title("HLA-A/B/C",fontsize=12)
#sns.kdeplot(df[allele+"1_CN"],df[allele+"2_CN"],shade=True,palette=cm.Greys,cut=0,shade_lowest=False,bw=0.1           )
ax.set_ylim(-0.5,6)
ax.set_xlim(-0.5,6)
ax.set_ylabel("Copy Number first allele HLA allele",fontsize=12)
ax.set_xlabel("Copy Number second allele  HLA allele",fontsize=12)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


ax.tick_params(axis='both', which='major', labelsize=12)
plt.savefig(f'plots/PCAWG_CN_MHCI.pdf', dpi=800,bbox_inches="tight")
plt.savefig(f'plots/PCAWG_CN_MHCI.png', dpi=800,bbox_inches="tight")

# %% [markdown]
# ### Proportion of samples with Copy Number in non-integer number (between 0.3 and 0.7)

# %%
from collections import defaultdict
k=defaultdict(int)
count=0
for a in ["A","B","C"]:
    for n1,n2 in zip(list(df[a+"1_CN"].values),list(df[a+"2_CN"])):
        if (n1 <= 0.3 or n1 >= 0.7) and (n2 <= 0.3 or n2 >= 0.7):
            k[a]+=1
            k["total"]+=1

# %% [markdown]
# ##### Compare to other random genes

# %%
for v,c in k.items():
    print (v,c/count)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-2693aec31cda> in <module>
#       1 for v,c in k.items():
# ----> 2     print (v,c/count)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Observe background genes :
# -- generated with /home/cog/fmartinez/scripts/organoids_CRC/hla_events/LOH/parse_cn_other_genes.py
# --- and stored at /hpc/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/hmf/lilac_validation/cn_other_genes.tsv

# %%
   df_genes = pd.read_csv(
        "/home/fran/Documents/cuppen/HPC/tunnel//cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/analysis/results/immune_escape/LOH/positive_selection/selected_regions.tsv",
        sep="\t")

# %%
genes=list(set(df_genes[~df_genes["gene"].str.contains("HLA")].sample(1000)["gene"]))
with open("tmp_pcawg.txt",'w') as f:
    f.write("\n".join(genes))

# %%
# !zgrep -f tmp_pcawg.txt /home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/pcawg/lilac_validation/cn_other_genes.tsv | gzip > data_selected_genes_pcawg.tsv.gz

# %%
dh = pd.read_csv("data_selected_genes_pcawg.tsv.gz",sep="\t",names=["gene","minMinorAlleleCopyNumber","minCopyNumber","sampleId"])
dh=dh[dh["sampleId"].isin(df["sampleId"].values)]
dh.set_index("gene",inplace=True)

# %%
genes=list(set(dh.index))

# %%
from collections import defaultdict
other=defaultdict(int)
data={}
for gene in tqdm(genes[0:1000]):
    tmp=dh.loc[gene]
    minors= list(tmp["minMinorAlleleCopyNumber"].values)
    majors = list(tmp["minCopyNumber"].values - minors)
    data[gene] = (minors,majors)
    for i in range(0,len(minors)):
        number_dec = minors[i]
        number_dec_2 = majors[i]
        if (number_dec <= 0.3 or number_dec >= 0.7) and (number_dec_2 <= 0.3 or number_dec_2 >= 0.7):
            other[gene]+=1
values=[]
for v,c in other.items():
    values.append(c/df.shape[0])
# Out:
# 100%|██████████| 1000/1000 [01:07<00:00, 14.74it/s]

# %%
other=defaultdict(int)
data={}
for gene in tqdm(genes[0:1000]):
    tmp=dh.loc[gene]
    minors= list(tmp["minMinorAlleleCopyNumber"].values)
    majors = list(tmp["minCopyNumber"].values - minors)
    data[gene] = (minors,majors)
    for i in range(0,len(minors)):
        number_dec = float(str(majors[i]-int(majors[i]))[1:])
        number_dec_2 = float(str(minors[i]-int(minors[i]))[1:])
        if (number_dec > 0.3 and number_dec < 0.7) or (number_dec_2 > 0.3 and number_dec_2 < 0.7):
            other[gene]+=1
values=[]
for v,c in other.items():
    values.append(c/df.shape[0])
# Out:
# 100%|██████████| 1000/1000 [01:45<00:00,  9.45it/s]

# %% [markdown]
# ### Plot barplot with comparison

# %%
fig,ax = plt.subplots(figsize=(3,4))
j=0
colors=["#760b23ff","#2d1a67ff","#063b07ff"]
for i,value in enumerate(k.items()):
    key,v=value
    if key !="total":
        ax.bar(x=j,height=v/df.shape[0],color="#ef8a62",width=0.6,edgecolor="black")
        j+=1
ax.bar(x=j,height=np.nanmean(values),yerr=np.nanstd(values),color="grey",width=0.6,edgecolor="black")
ax.set_xticks(range(0,4))
ax.set_xticklabels(["HLA-A","HLA-B","HLA-C","Other genes"],rotation=90)

ax.set_ylabel("Prop. of samples with integer copy number \n (minor and major CN <=0.3 or >= 0.7)",fontsize=12)
ax.set_xlabel("Gene",fontsize=12)

ax.tick_params(axis='both', which='major', labelsize=12)
    
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.savefig(f'plots/PCAWG_CN_comparison_MHCI.pdf', dpi=800,bbox_inches="tight")

# %% [markdown]
# ### Plot random gene...

# %%
import random

# %%
fig,ax = plt.subplots(figsize=(5,5))
gene = dh.sample(1).index[0]
ax.scatter(data[gene][0],data[gene][1],alpha=0.1,color="black",s=15)
    
ax.set_title(gene)
#sns.kdeplot(df[allele+"1_CN"],df[allele+"2_CN"],shade=True,palette=cm.Greys,cut=0,shade_lowest=False,bw=0.1           )
ax.set_ylim(-0.5,6)
ax.set_xlim(-0.5,6)
ax.set_ylabel("Copy Number first allele HLA allele")
ax.set_xlabel("Copy Number second allele  HLA allele")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-49e9a00ffdc2> in <module>
#       1 fig,ax = plt.subplots(figsize=(5,5))
#       2 gene = dh.sample(1).index[0]
# ----> 3 ax.scatter(data[gene][0],data[gene][1],alpha=0.1,color="black",s=15)
#       4
#       5 ax.set_title(gene)
#
# KeyError: 'ACTR1B'

# %%
df_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-de7fbce2df6a> in <module>
# ----> 1 df_info
#
# NameError: name 'df_info' is not defined

# %% [markdown]
# ###
