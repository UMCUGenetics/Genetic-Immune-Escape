# %%
import glob
import os
import pandas as pd
import numpy as np
import tqdm as tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ----

# %% [markdown]
# ### Important
#
# For each cancer type as well as the pan-cancer cohort we run dndscv with default options in both Hartwig and PCAWG samples:
#
# 1. To estimate global MHC-I (combining HLA-A, HLA-B and HLA-C) dn/ds ratios. Only in pancancer manner.
# 2. To estimate the gene-specific and pan-cancer dN/dS ratios in a pan-cancer manner for MHC-I genes.
# 3. To identify positively selected genes by recurrent mutation of the list of 21 genes selected for anylsis in this publication (see Supp. Table 1). This analysis is performed in a pan-cancer and cancer type specific manner.
#
# The script scripts/positive_selection/mutations/run_driver_pipeline_dndscv.py was used to run the Hartwig and PCAWG a pan-cancer and cancer type specific analyses.
# This scripts uses scripts/positive_selection/mutations/run_dndscv.R to compute the dndscv driver genes and dN/dS ratios

# %% [markdown]
# ### Genes

# %%
# hla locus
mhc_I = ["HLA-A","HLA-B","HLA-C"]
# APP related proteins
transport_mhc = ["TAP1","TAP2","TAPBP"]
scaffold_mhc = ["B2M","CALR"]
#interferon
interferon=["JAK1","JAK2","STAT1","IRF2","APLNR","IFNGR1", "IFNGR2"]
#TFs HLA locus
tfs=["NLRC5","RFX5","CIITA"]
# CD58
cd58_nk = ["CD58"]
d_data = {"MHC-I":mhc_I,"transport_mhc":transport_mhc,"scaffold_mhc":scaffold_mhc,"IFN-gamma":interferon,"Activators-MHC":tfs,"cd58_nk":cd58_nk}
pallete = {"wt":"#ef8a62","alteration":"#67a9cf","alteration_primary":"#7570b3"}

# %%
total= []
for k in d_data:
    total+=d_data[k]

# %% [markdown]
# ### Metastasis

# %%
l,l1=[], []
for filein in glob.glob("/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/hmf/positive_selection/dndscv/*.ci.tsv.gz"):
    ttype = os.path.basename(filein).split(".")[0]
    df = pd.read_csv(filein,sep="\t")
    df_d = pd.read_csv(filein.replace(".ci.",".results."),sep="\t")
    df=df[df["gene"].isin(total)]
    df_d = df_d[df_d["gene_name"].isin(total)]
    df["ttype"] = ttype
    df_d["ttype"] = ttype
    l.append(df)
    l1.append(df_d)
df_total = pd.concat(l)
df_total_d = pd.concat(l1)

# %%
df_total_d.sort_values("qglobal_cv").to_csv("../results/data/dndscv_output_immune_genes_hmf.tsv.gz",sep="\t",index=False,compression="gzip")
df_total_d[df_total_d["qglobal_cv"]<.1].to_csv("../results/data/MUT_positive_selection_HMF.tsv",sep="\t")

# %%
df_total_d[df_total_d["qglobal_cv"]<.1]
# Out:
#    gene_name  n_syn  n_mis  n_non  n_spl  n_ind     wmis_cv      wnon_cv  \
# 13      CD58      0      3      0      0      1  336.748852     0.000000
# 16     HLA-B      0      0      1      0      2    0.000000  1371.287781
# 12       B2M      1      1      0      0      3   11.911040     0.000000
# 17       B2M      0      3      2      1      7    7.545842    82.950659
# 29     HLA-B      1      8      1      0      6    5.160554    11.138516
# 47     HLA-A      1      3      2      0      5    1.844576    20.150373
# 14       B2M      0      3      0      1      3   10.066629    47.654570
# 28       B2M      2     15      9      4     16    3.731710    33.698190
# 48     HLA-A     11     24     15      2     14    1.462092    10.899306
# 64     HLA-B     12     26      7      2     19    1.548579     5.937452
# 10      JAK1      1      4      1      1      6    2.642344    12.822432
#
#         wspl_cv     wind_cv   pmis_cv     ptrunc_cv   pallsubs_cv  \
# 13     0.000000  212.661070  0.000007  9.684713e-01  4.064594e-05
# 7947    HLA-A  1.462092  10.899306  0.818425   5.707021  2.624957  20.460065
# 7948    HLA-B  1.548579   5.937452  0.883128   2.602499  2.733253  12.407409
# 7949    HLA-C  1.876695   0.842009  1.029243   0.046822  3.491726   4.076144
# 8326   IFNGR1  1.197972   1.976353  0.597540   0.455646  2.452043   6.056880
# 8327   IFNGR2  0.813689   1.604058  0.329886   0.253658  1.850276   5.637941
# 8614     IRF2  0.860443   2.782550  0.437618   0.931828  1.646090   6.787711
# 8732     JAK1  1.662978   3.122770  1.036161   1.464187  2.757530   6.263228
# 8733     JAK2  1.275314   2.568104  0.778792   1.277406  2.165301   5.006519
# 11437   NLRC5  1.383470   1.311535  0.978288   0.600565  1.984594   2.550988
# 14438    RFX5  0.511620   0.000000  0.251892   0.000000  0.995167   0.772744
# 16826   STAT1  1.397059   2.248541  0.782972   0.874040  2.561789   5.162571
# 17135    TAP1  1.133272   0.774384  0.676554   0.124792  1.916119   2.590120
# 17136    TAP2  1.054902   1.445570  0.569878   0.340616  1.958901   4.216560
# 17137   TAPBP  0.931678   2.083965  0.468857   0.491039  1.811981   6.078682
#
#            ttype
# 1311   pancancer
# 1821   pancancer
# 2920   pancancer
# 3383   pancancer
# 3819   pancancer
# 7947   pancancer
# 7948   pancancer
# 7949   pancancer
# 8326   pancancer
# 8327   pancancer
# 8614   pancancer
# 8732   pancancer
# 8733   pancancer
# 11437  pancancer
# 14438  pancancer
# 16826  pancancer
# 17135  pancancer
# 17136  pancancer
# 17137  pancancer

# %% [markdown]
# ### PCAWG

# %%
l,l1=[], []
for filein in glob.glob("/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/pcawg/positive_selection/dndscv/*.ci.tsv.gz"):
    ttype = os.path.basename(filein).split(".")[0]
    df = pd.read_csv(filein,sep="\t")
    df_d = pd.read_csv(filein.replace(".ci.",".results."),sep="\t")
    df=df[df["gene"].isin(total)]
    df_d = df_d[df_d["gene_name"].isin(total)]
    df["ttype"] = ttype
    df_d["ttype"] = ttype
    l.append(df)
    l1.append(df_d)
df_total = pd.concat(l)
df_total_d = pd.concat(l1)

# %%
df_total_d.sort_values("qglobal_cv").to_csv("../results/data/dndscv_output_immune_genes_pcawg.tsv.gz",sep="\t",index=False,compression="gzip")
df_total_d[df_total_d["qglobal_cv"]<.1].to_csv("../results/data/MUT_positive_selection_PCAWG.tsv",sep="\t")

# %%
df_total_d[df_total_d["qglobal_cv"]<.1]
# Out:
#    gene_name  n_syn  n_mis  n_non  n_spl  n_ind    wmis_cv     wnon_cv  \
# 3        B2M      0     11      5      1      5  61.618363  371.500360
# 13      CD58      0      0      2      2      1   0.000000  258.961580
# 18     HLA-B      0      5      2      1      1  22.475429  177.715000
# 9        B2M      1     17      6      1      7  14.978107   65.820672
# 28     HLA-A      3      5      7      2      5   1.403459   25.353874
# 35     HLA-B      1     13      2      2      7   4.697558   15.264558
# 68      CD58      0      3      3      2      3   1.301947   18.968152
#
#        wspl_cv     wind_cv       pmis_cv     ptrunc_cv   pallsubs_cv  \
# 3   371.500360  108.028419  1.711530e-09  1.143907e-11  1.509903e-14
# 13  258.961580   65.682088  5.936073e-01  3.161678e-08  1.188904e-07
# 18  177.715000   31.913489  1.337234e-04  2.174982e-06  4.686941e-07
# 9    65.820672   33.929853  2.652700e-11  1.520341e-10  0.000000e+00
# 28   25.353874    9.378269  5.336295e-01  1.989837e-09  1.429466e-08
# 35   15.264558   13.513120  2.746188e-04  2.906790e-04  1.105880e-05
# 68   18.968152    9.086144  6.981241e-01  2.321816e-05  1.261295e-04
#
#          pind_cv       qmis_cv     qtrunc_cv   qallsubs_cv    pglobal_cv  \
# 3   1.029211e-05  4.912334e-06  7.660746e-08  7.583867e-11  0.000000e+00
# 13  1.463931e-02  8.036403e-01  9.074468e-05  1.492892e-04  3.684426e-08
# 18  2.896927e-02  7.462878e-02  3.972507e-03  4.708266e-04  2.595360e-07
# 9   2.535773e-08  4.099646e-08  2.349628e-07  0.000000e+00  0.000000e+00
# 28  5.923218e-04  9.736949e-01  2.498613e-06  1.025693e-05  2.243328e-10
# 35  9.405607e-06  1.103473e-01  1.358147e-01  4.534335e-03  2.494949e-09
# 68  6.334899e-03  9.839546e-01  1.504761e-02  4.445735e-02  1.201714e-05
#
#       qglobal_cv                             ttype
# 3   0.000000e+00  Diffuse__large__B-cell__lymphoma
# 13  5.287414e-05  Diffuse__large__B-cell__lymphoma
# 18  2.744388e-04  Diffuse__large__B-cell__lymphoma
# 9   0.000000e+00                         pancancer
# 28  1.554162e-07                         pancancer
# 35  1.392389e-06                         pancancer
# 68  3.499077e-03                         pancancer

# %%
df_total[df_total["ttype"]=="pancancer"]
# Out:
#          gene    mis_mle    tru_mle   mis_low    tru_low   mis_high  \
# 1311    APLNR   1.928298   0.000000  0.877057   0.000000   4.267048
# 1821      B2M  14.978107  65.820672  7.000784  23.972262  33.716361
# 2920     CALR   0.559939   0.000000  0.129846   0.000000   1.693370
# 3383     CD58   1.301947  18.968152  0.289591   5.846961   4.338929
# 3819    CIITA   0.764091   3.527758  0.373166   1.178649   1.505339
# 7947    HLA-A   1.403459  25.353874  0.447406  10.374602   3.769648
# 7948    HLA-B   4.697558  15.264558  2.074182   4.197229  10.933958
# 7949    HLA-C   3.122262   3.758362  1.244510   0.205062   7.699601
# 8326   IFNGR1   1.286790   0.000000  0.439064   0.000000   3.445995
# 8327   IFNGR2   0.376331   2.988823  0.020613   0.163709   1.929414
# 8614     IRF2   2.412090  16.522258  0.865223   5.093011   6.428905
# 8732     JAK1   1.615314   2.178980  0.737403   0.337666   3.621122
# 8733     JAK2   1.814570   0.626555  0.916384   0.034431   3.766854
# 11437   NLRC5   1.062346   2.074684  0.565838   0.601974   1.999836
# 14438    RFX5   0.767045   0.000000  0.213004   0.000000   2.233800
# 16826   STAT1   1.284790   3.858738  0.531277   1.088379   2.966883
# 17135    TAP1   0.879870   1.605154  0.309702   0.088453   2.219012
# 17136    TAP2   1.024614   0.000000  0.323579   0.000000   2.804562
# 17137   TAPBP   0.497263   2.814838  0.077483   0.154683   1.818211
#
#          tru_high      ttype
# 1311     6.169914  pancancer
# 1821   170.398574  pancancer
# 2920     3.685393  pancancer
# 3383    54.551348  pancancer
# 3819     8.643785  pancancer
# 7947    59.644766  pancancer
# 7948    45.407432  pancancer
# 7949    19.559046  pancancer
# 8326     4.630625  pancancer
# 8327    15.323415  pancancer
# 8614    47.517092  pancancer
# 8732     8.086914  pancancer
# 8733     3.172398  pancancer
# 11437    5.511350  pancancer
# 14438    3.981390  pancancer
# 16826   10.871641  pancancer
# 17135    8.041571  pancancer
# 17136    4.162755  pancancer
# 17137   14.252185  pancancer
