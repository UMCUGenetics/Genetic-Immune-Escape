# %%
import pandas as pd

import os 
import pandas as pd
    
import json
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob
import allel
import itertools
from matplotlib import gridspec
import matplotlib.pyplot as plt
import pickle
from statannot import add_stat_annotation
from scipy import stats
import matplotlib.cm as cm
import matplotlib

from math import pi
import scipy

import matplotlib.patches as mpatches
import re


import matplotlib.colors as clr
from matplotlib.colors import ListedColormap, LinearSegmentedColormap, BoundaryNorm
from matplotlib import collections  as mc
import matplotlib.lines as mlines

# %%
df = pd.read_csv("../results/data/processed_hmf_escape_info.tsv.gz",sep="\t")
df_pcawg = pd.read_csv("../results/data/processed_pcawg_escape_info.tsv.gz",sep="\t")
df_meta = pd.read_csv("../metadata/dataset_metadata_supp_table3.tsv",sep="\t")
# Out:
# /home/fran/miniconda3/envs/global/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (16,20,142) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Needle plot

# %% [markdown]
# ##### HMF

# %%
def plot_hla(gene,total_cds,d_h,summary,cohort="HMF",ylim=8,synonymous=False):
    colors={"missense_variant/inframe_variant":"#66c2a5","truncating_variant":"#fc8d62","splice_variant":"#8da0cb","synonymous":"grey"}
    residues=np.array(list(set([31,83,86,87,90,183,187,191,195,31,33,48,69,86,87,90,91,94,123,183,94,121,123,138,180,183,90,182,183,187,93,94,182,93,94,97,98,121,180,93,97,121,138,171,174,176,180,97,100,101,171,98,101,104,105,108,119,121,140,142,167,171])))*3

    fig,ax = plt.subplots(figsize=(10,4))

    ax.axhline(y=-0.4,xmin=0,xmax=total_cds,color="black",lw=5)

    ax.set_ylim(-2,ylim+2)
    ax.set_xlim(-1,total_cds+1)

    # plot domains
    for region in d_h["regions"]:
        start,end,text,descr=(region["start"]*3,region["end"]*3,region["text"],region["metadata"]["description"])
        rect=mpatches.Rectangle(xy=(start,-0.8),width=end-start,height=1,zorder=3,color="#888888")
                            # Add the patch to the Axes
        ax.annotate(xy=((start+((end-start)/2)),-0.4),s=text,fontsize=14)
        ax.add_patch(rect)

    # mutations
    mut_gene=summary.loc[gene]
    if not(synonymous):
        mut_gene=mut_gene[mut_gene["type_mut"]!="synonymous"]
    else:
        mut_gene=mut_gene[mut_gene["type_mut"]=="synonymous"]
    for csq in mut_gene["type_mut"].unique():
        color=colors[csq]
        for i,r in mut_gene[mut_gene["type_mut"]==csq].iterrows():
            try:
                ax.bar(x=int(r["cds_pos"]),height=r["sample"],color=color,width=3.5)
                ax.scatter(x=int(r["cds_pos"]),y=r["sample"],s=80,color=color,edgecolors="black",lw=1.,zorder=3)
            except ValueError:
                continue
    # highlit residues involved in binding

    for res in residues:
        ax.scatter(x=res,y=-1.5,color="#cc0000",marker="_",s=70)


    ax.set_title(gene,fontsize=14)
    ax.set_ylabel(f"Number of observed mutations \n ({cohort} cohort)",fontsize=12)
    ax.set_xlabel("CDS pos",fontsize=12)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', which='major', labelsize=12)
    #plt.savefig(f'example_plots/needle_{gene}_{cohort}.pdf', dpi=800,bbox_inches="tight")
def get_type_mut(csq):
    if "missense_variant" in csq or "inframe_insertion" in csq or "inframe_deletion" in csq:
        return "missense_variant/inframe_variant"
    elif "stop_gained" in csq or "frameshift_variant" in csq or "stop_lost" in csq:
        return "truncating_variant"
    elif "splice_acceptor_variant" in csq or "splice_donor_variant" in csq or "splice_region_variant" in csq: 
        return "splice_variant"
    elif "synonymous_variant" in csq:
        return "synonymous"
    else:
        return "other"

# %%
import re
m=re.compile("PURPLE_AF=([0-9\.]+)")
m1=re.compile("PURPLE_VCN=([0-9\.]+)")

# %%
f"/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/hmf/lilac/{sample}/{sample}.lilac.somatic.vcf.gz"
# Out:
# '/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/hmf/lilac/WIDE01011142T/WIDE01011142T.lilac.somatic.vcf.gz'

# %%
df_met = df[(df["cohort"]=="Hartwig")&(df["is_selected"])]
print (df_met.shape[0])
l=[]
lenghts={}
for sample in tqdm(df_met["sample_id"].values):
    if not(os.path.exists(f"/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/hmf/lilac/{sample}/{sample}.lilac.somatic.vcf.gz")):
        continue
    try:
        dq = pd.read_csv(f"/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/hmf/lilac/{sample}/{sample}.lilac.somatic.vcf.gz",sep="\t",skiprows=94)
    except:
        dq = pd.read_csv(f"/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/hmf/lilac/{sample}/{sample}.lilac.somatic.vcf.gz",sep="\t",skiprows=97)
    for i,r in dq.iterrows():
        csq,gene,cds_pos,protein_pos = map(r["INFO"].split("|").__getitem__,[1,3,12,13])
        caf = float(m.search(r["INFO"])[1])
        vcn = float(m1.search(r["INFO"])[1])
        vaf = float(r[sample].split(":")[2])
        if not(gene) in lenghts:
            lenghts[gene] = (protein_pos.split("/")[1],cds_pos.split("/")[1])
        l.append([gene,csq,sample,protein_pos.split("/")[0],cds_pos.split("/")[0],caf,vcn,vaf])
df_muts_hla = pd.DataFrame(l,columns=["gene","csq","sample","protein_pos","cds_pos","purple_vaf","variant_cn","raw_vaf"])
df_muts_hla["type_mut"] = df_muts_hla.apply(lambda row: get_type_mut(row["csq"]),axis=1)
summary=df_muts_hla.groupby(["gene","type_mut","cds_pos"]).agg({"sample":"count"}).reset_index().set_index(["gene"])
# Out:
#   0%|          | 0/4472 [00:00<?, ?it/s]
# 4472
#   0%|          | 1/4472 [00:00<26:20,  2.83it/s]
#
#   0%|          | 3/4472 [00:00<20:11,  3.69it/s]
#
#   0%|          | 5/4472 [00:00<15:52,  4.69it/s]
#
#   0%|          | 7/4472 [00:00<13:00,  5.72it/s]
#
#   0%|          | 9/4472 [00:01<11:07,  6.69it/s]
#
#   0%|          | 11/4472 [00:01<09:31,  7.81it/s]
#
#   0%|          | 13/4472 [00:01<08:41,  8.55it/s]
#
#   0%|          | 15/4472 [00:01<07:54,  9.39it/s]
#
#   0%|          | 17/4472 [00:01<07:17, 10.19it/s]
#
#   0%|          | 19/4472 [00:01<06:56, 10.70it/s]
#
#   0%|          | 21/4472 [00:02<08:29,  8.73it/s]
#
#   1%|          | 23/4472 [00:02<07:48,  9.49it/s]
#
#   1%|          | 25/4472 [00:02<07:18, 10.13it/s]
#
#   1%|          | 27/4472 [00:02<06:53, 10.74it/s]
#
#   1%|          | 29/4472 [00:02<06:35, 11.22it/s]
#
#   1%|          | 31/4472 [00:03<06:35, 11.23it/s]
#
#   1%|          | 33/4472 [00:03<06:30, 11.38it/s]
#
# ...

# %% [markdown]
# ### Recurrent frameshift info

# %%
df_muts_hla[df_muts_hla["sample"]=="CPCT02120042T"]
# Out:
#       gene                                       csq         sample  \
# 113  HLA-A  frameshift_variant&splice_region_variant  CPCT02120042T
# 114  HLA-A  frameshift_variant&splice_region_variant  CPCT02120042T
# 115  HLA-C                          missense_variant  CPCT02120042T
# 116  HLA-C                        frameshift_variant  CPCT02120042T
# 117  HLA-C                          missense_variant  CPCT02120042T
# 118  HLA-B                          missense_variant  CPCT02120042T
# 119  HLA-B                        frameshift_variant  CPCT02120042T
#
#     protein_pos cds_pos  purple_vaf  variant_cn  raw_vaf  \
# 113         207     621      0.6004       1.200    0.306
# 114         207     621      0.3355       0.671    0.171
# 115           9      25      0.5839       1.170    0.298
# 116           7      19      0.5600       1.120    0.286
# 117           4      11      0.5600       1.120    0.286
# 118         283     848      0.3187       0.638    0.163
# ...

# %%
df_meta[df_meta["sample_id"].isin(df_muts_hla[df_muts_hla["cds_pos"]=="621"]["sample"])][["sample_id","msi_status"]]
# Out:
#           sample_id msi_status
# 1081  CPCT02120042T        MSI
# 1133  DRUP01010018T        MSI
# 1740  WIDE01010578T        MSI
# 2689  CPCT02030546T        MSI
# 2861  CPCT02011050T        MSI
# 4421  DRUP01010123T        MSI

# %%
df_muts_hla[(df_muts_hla["cds_pos"]=="19")&(df_muts_hla["gene"]=="HLA-B")]
# Out:
#       gene                 csq         sample protein_pos cds_pos  purple_vaf  \
# 18   HLA-B         stop_gained  CPCT02230086T           7      19      0.3576
# 37   HLA-B    missense_variant  WIDE01010625T           7      19      0.9077
# 49   HLA-B  frameshift_variant  DRUP01070001T           7      19      0.4320
# 119  HLA-B  frameshift_variant  CPCT02120042T           7      19      0.5524
# 174  HLA-B  frameshift_variant  CPCT02050279T           7      19      1.2094
#
#      variant_cn  raw_vaf                          type_mut
# 18        0.755    0.162                truncating_variant
# 37        1.840    0.845  missense_variant/inframe_variant
# 49        0.934    0.146                truncating_variant
# 119       1.110    0.282                truncating_variant
# 174       2.410    0.313                truncating_variant

# %%
df_meta[df_meta["sample_id"].isin(df_muts_hla[(df_muts_hla["cds_pos"]=="19")&(df_muts_hla["gene"]=="HLA-B")]["sample"])][["sample_id","msi_status"]]
# Out:
#           sample_id msi_status
# 1052  CPCT02050279T        MSI
# 1081  CPCT02120042T        MSI
# 1334  DRUP01070001T        MSI
# 1593  WIDE01010625T        MSS
# 2698  CPCT02230086T        MSI

# %% [markdown]
# ##### Plot it

# %%
with open("../metadata/external/P04439_HLAA.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-A"][1])
plot_hla("HLA-A",total_cds,d_h,summary)
with open("../metadata/external/P01889_HLAB.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-B"][1])
plot_hla("HLA-B",total_cds,d_h,summary)
with open("../metadata/external/P10321_HLAC.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-C"][1])
plot_hla("HLA-C",total_cds,d_h,summary)

# %%
df_met[df_met["sample_id"]=="CPCT02010878T"]["cancer_type"]
# Out:
# 4317    Penile cancer
# Name: cancer_type, dtype: object

# %%
df_muts_hla[(df_muts_hla["cds_pos"]=="675")&(df_muts_hla["gene"]=="HLA-A")]
# Out:
#       gene                 csq           sample protein_pos cds_pos  \
# 80   HLA-A  synonymous_variant  CPCT02010878TII         225     675
# 197  HLA-A  synonymous_variant    CPCT02010878T         225     675
#
#      purple_vaf  variant_cn  raw_vaf    type_mut
# 80       0.5457        1.10    0.350  synonymous
# 197      0.5875        1.19    0.413  synonymous

# %%
with open("../metadata/external/P04439_HLAA.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-A"][1])
plot_hla("HLA-A",total_cds,d_h,summary,synonymous=True)
with open("../metadata/external/P01889_HLAB.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-B"][1])
plot_hla("HLA-B",total_cds,d_h,summary,synonymous=True)
with open("../metadata/external/P10321_HLAC.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-C"][1])
plot_hla("HLA-C",total_cds,d_h,summary,synonymous=True)

# %% [markdown]
# ### PCAWG

# %%
r
# Out:
# #CHROM                                                       6
# POS                                                   29912155
# ID                                                           .
# REF                                                          G
# ALT                                                        GCC
# QUAL                                                        80
# FILTER                                                    PASS
# INFO         ANN=GCC|frameshift_variant|HIGH|HLA-A|ENSG0000...
# FORMAT       GT:AD:AF:DP:RABQ:RAD:RC_CNT:RC_IPC:RC_JIT:RC_Q...
# DO220886R    0/0:44,0:0:44:1562,0:48,0:0,0,0,0,44,44:0:0,0,...
# DO220886T    0/1:28,8:0.222:36:1030,275:29,8:8,0,0,0,28,36:...
# Name: 0, dtype: object

# %%
df_primary = df_pcawg[(df_pcawg["cohort"]=="PCAWG")&(df_pcawg["is_selected"])]
print (df_primary.shape[0])
l=[]
lenghts={}
for sample in tqdm(df_primary["sample_id"].values):
    if not(os.path.exists(f"/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/pcawg/lilac/{sample}/{sample}.lilac.somatic.vcf.gz")):
        continue
    try:
        dq = pd.read_csv(f"/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/pcawg/lilac/{sample}/{sample}.lilac.somatic.vcf.gz",sep="\t",skiprows=91)
    except:
        print (error)
        dq = pd.read_csv(f"/home/fran/Documents/cuppen/HPC/tunnel/cuppen/projects/P0020_genetics_immune_escape/large_scale_primary_met/processed/pcawg/lilac/{sample}/{sample}.lilac.somatic.vcf.gz",sep="\t",skiprows=97)
    for i,r in dq.iterrows():
        csq,gene,cds_pos,protein_pos = map(r["INFO"].split("|").__getitem__,[1,3,12,13])
        caf = float(m.search(r["INFO"])[1])
        vcn = float(m1.search(r["INFO"])[1])
        vaf = float(r[sample+"T"].split(":")[2])
        if not(gene) in lenghts:
            lenghts[gene] = (protein_pos.split("/")[1],cds_pos.split("/")[1])
        l.append([gene,csq,sample,protein_pos.split("/")[0],cds_pos.split("/")[0],caf,vcn,vaf])
df_muts_hla_primary = pd.DataFrame(l,columns=["gene","csq","sample","protein_pos","cds_pos","purple_vaf","variant_cn","raw_vaf"])
df_muts_hla_primary["type_mut"] = df_muts_hla_primary.apply(lambda row: get_type_mut(row["csq"]),axis=1)
summary_primary=df_muts_hla_primary.groupby(["gene","type_mut","cds_pos"]).agg({"sample":"count"}).reset_index().set_index(["gene"])
# Out:
#   0%|          | 0/1880 [00:00<?, ?it/s]
# 1880
#   0%|          | 1/1880 [00:00<10:57,  2.86it/s]
#
#
#
#   0%|          | 3/1880 [00:00<08:24,  3.72it/s]
#
#
#
#   0%|          | 5/1880 [00:00<06:37,  4.71it/s]
#
#
#
#   0%|          | 7/1880 [00:00<05:23,  5.79it/s]
#
#
#
#   0%|          | 9/1880 [00:00<04:32,  6.88it/s]
#
#
#
#   1%|          | 11/1880 [00:01<03:56,  7.92it/s]
#
#
#
#   1%|          | 13/1880 [00:01<03:29,  8.90it/s]
#
#
#
#   1%|          | 15/1880 [00:01<03:14,  9.57it/s]
#
#
#
#   1%|          | 17/1880 [00:01<03:00, 10.31it/s]
#
#
#
#   1%|          | 19/1880 [00:01<02:51, 10.87it/s]
#
#
#
#   1%|          | 21/1880 [00:01<02:47, 11.13it/s]
#
#
#
#   1%|          | 23/1880 [00:02<02:41, 11.50it/s]
#
#
#
#   1%|▏         | 25/1880 [00:02<02:48, 11.02it/s]
#
#
#
#   1%|▏         | 27/1880 [00:02<02:42, 11.41it/s]
#
#
#
#   2%|▏         | 29/1880 [00:02<02:38, 11.68it/s]
#
#
#
#   2%|▏         | 31/1880 [00:02<02:33, 12.01it/s]
#
#
#
# ...

# %% [markdown]
# ##### Plot it

# %%
with open("P04439_HLAA.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-A"][1])
plot_hla("HLA-A",total_cds,d_h,summary,cohort="PCAWG",ylim=5)
with open("P01889_HLAB.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-B"][1])
plot_hla("HLA-B",total_cds,d_h,summary,cohort="PCAWG",ylim=5)
with open("P10321_HLAC.json") as f:
    d_h=json.load(f)
total_cds=int(lenghts["HLA-C"][1])
plot_hla("HLA-C",total_cds,d_h,summary,cohort="PCAWG",ylim=5)
