# %%
import os 
import pandas as pd
    
import json
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob
import allel
import itertools
from matplotlib import gridspec
import matplotlib.pyplot as plt
import pickle
from statannot import add_stat_annotation
from scipy import stats
import matplotlib.cm as cm
import matplotlib

from math import pi
import scipy

# %%
pd.options.display.max_columns=200
pd.options.display.max_rows=100
from pandas.core.common import SettingWithCopyWarning
import warnings
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
path_escape="../results/data/raw_data_gie_pcawg.tsv" # change this with your path
path_rna="../results/data/raw_data_immune_pcawg.tsv" # change this with your path

# %%
def prepare_metadata():
    df_meta = pd.read_csv("../metadata/dataset_metadata_supp_table3.tsv",sep="\t")
    df_meta=df_meta[(df_meta["is_selected"]==True)]
    return df_meta[df_meta["cohort"]=="PCAWG"]

# %% [markdown]
# # Important:
#
# The file with the processed genetic immune escaped alterations and the inmmune infiltration per sample were generated as:
#
# - <../results/data/raw_data_gie_pcawg.tsv> has been generated using the script scripts/process_data/pipeline_hla_events_PCAWG.py across all PCAWG samples.
#
# - This script runs for each sample in PCAWG the script <scripts/process_data/analyze_events_APP.py> and <scripts/process_data/create_report_summary.py> to process the GIE events per sample
#
# - For the immune infiltration scores <../results/data/raw_data_immune_pcawg.tsv>  we used the script <scripts/process_data/get_scores_infiltration.py> across all PCAWG samples with avaliable RNA-seq data.

# %%
df = pd.read_csv(f"{path_escape}",sep="\t").rename(columns={"sample":"sample_id"})
df_metadata = prepare_metadata()
df=df.merge(df_metadata)
df_rna = pd.read_csv(f"{path_rna}",sep="\t")
df = df.merge(df_rna,how="left")
summary_cohort = pd.read_csv("../metadata/table_cancer_types_info.tsv",sep="\t")

# %%
df.shape
# Out:
# (1880, 135)

# %% [markdown]
# ### Define alterations to be considered

# %%
allowed_csq = set(["frameshift_variant","stop_gained","stop_lost","splice_acceptor_variant","splice_donor_variant","stop_gained","splice_region_variant","start_lost"]) # monoallelic
allowed_csq_biallelic = set(["missense_variant","structural_interaction_variant","conservative_inframe_deletion","conservative_inframe_insertion","disruptive_inframe_deletion","disruptive_inframe_insertion"]) # only biallelic 
alterations = pd.read_csv("../metadata/immune_selected_genes.tsv",sep="\t")
alterations=alterations[alterations["Selected"]]

def app_pathway(row):
    selected_genes = alterations[alterations["Pathway_general"]=="Antigen Presentation Pathway"]["Gene"].values
    for gene in selected_genes:
        if (gene in str(row["del_scaffold_mhc"])) or (gene in str(row["del_tfs"])) or (gene in str(row["del_transport_mhc"])): 
            return pd.Series([True, f"del {gene}"])
        elif (is_clonally_mutated(gene,row["mut_scaffold_mhc"]) or (is_clonally_mutated(gene, row["mut_tfs"])) or (is_clonally_mutated(gene, row["mut_transport_mhc"]))):
            return pd.Series([True, f"mut {gene}"])
    return pd.Series([False,""])
            
def ifn_gamma_pathway(row):
    selected_genes=alterations[alterations["Pathway_general"]=="IFN-gamma pathway"]["Gene"].values
    for gene in selected_genes:
        if (gene in str(row["del_interferon"])): 
            return pd.Series([True, f"del {gene}"])
        elif (is_clonally_mutated(gene,row["mut_interferon"])):
            return pd.Series([True, f"mut {gene}"])
    return pd.Series([False,""])

def cd58_pathway(row):
    selected_genes=["CD58"]
    for gene in selected_genes:
        if (gene in str(row["del_cd58"])): 
            return pd.Series([True, f"del {gene}"])
        elif (is_clonally_mutated(gene,row["mut_cd58"])):
            return pd.Series([True, f"mut {gene}"])
    return pd.Series([False,""])

def checkpoint_pathway(row):
    genes = ["CD274"]
    for gene in genes:
        if gene in str(row["amps_inhibitors"]):
            return pd.Series([True,f"amp {gene}"])
    return pd.Series([False,""])

def epigenetic_regulators_pathway(row):
    genes = ["SETDB1"]
    for gene in genes:
        if gene in str(row["epigenetic_regulators"]):
            return pd.Series([True,f"amp {gene}"])
    return pd.Series([False,""])

def is_clonally_mutated(gene,muts):
    if not(";") in str(muts):
        return False
    muts_gene=0
    for mut in muts.split("___"):
       
        gene_mut,csq,allelic_status,germline_status,clonality_purple,clonality_timing,af,cn,macn=mut.split(";")
         
        if gene == gene_mut and (clonality_purple.startswith("clonal"))  and (len(set(csq.split("&")).intersection(allowed_csq))) >0: 
            return True # At least one clonal deleterios mutations
        if gene == gene_mut and (clonality_purple.startswith("clonal")) and allelic_status == "biallelic" and (len(set(csq.split("&")).intersection(allowed_csq_biallelic))) >0 :
            return True # At least one biallelic deleterios or non-synonymous likely impactful mutation (missense)
        if gene == gene_mut and (clonality_purple.startswith("clonal")) and allelic_status == "monoallelic" and (len(set(csq.split("&")).intersection(allowed_csq_biallelic))) >0:
            muts_gene+=1 # multiple non-synonymous monoallelic mutations
    return muts_gene>1 # multipl, at least two, non-synonymous monoallelic mutations

# %% [markdown]
# ### Define type of alterations

# %%
df[["systemic_app_pathway","systemic_app_pathway_detail"]]  = df.apply(lambda row: app_pathway(row),axis=1)          
df[["cd58_pathway","cd58_pathway_detail"]]  = df.apply(lambda row: cd58_pathway(row),axis=1)          
df[["ifn_gamma_pathway","ifn_gamma_pathway_detail"]]  = df.apply(lambda row: ifn_gamma_pathway(row),axis=1)          
df[["checkpoint_pathway","checkpoint_pathway_detail"]]  = df.apply(lambda row: checkpoint_pathway(row),axis=1)
df[["epigenetic_regulators_pathway","epigenetic_regulators_pathway_detail"]]  = df.apply(lambda row: epigenetic_regulators_pathway(row),axis=1)
df["targeted_app_pathway_mut_HLA"] = df.apply(lambda row: row["mut_hla_lilac"],axis=1)
df["targeted_app_pathway_loh_HLA"] = df.apply(lambda row: row["loh_lilac"] ,axis=1)
df["targeted_app_pathway_del_HLA"] = df.apply(lambda row: (row["del_HLA-A"] == 1.) | (row["del_HLA-B"] == 1.) | (row["del_HLA-C"] == 1.) ,axis=1)
df["targeted_app_pathway_partdel_HLA"] = df.apply(lambda row: row["targeted_app_pathway_loh_HLA"] | row["targeted_app_pathway_del_HLA"] ,axis=1)
df["targeted_escape"] = df["targeted_app_pathway_mut_HLA"] | df["targeted_app_pathway_loh_HLA"] | df["targeted_app_pathway_del_HLA"]
df["non_targeted_escape"] = df["systemic_app_pathway"] | df["ifn_gamma_pathway"] | df["checkpoint_pathway"] | df["cd58_pathway"] | df["epigenetic_regulators_pathway"]
df["genetic_immune_escape"] = df["targeted_escape"] | df["non_targeted_escape"]

# %% [markdown]
# ### Type of LOH HLA (copy number neutral or dosage imbalance)

# %%
def get_copy_number_neutral_loh(row):
    if not(row["loh_lilac"]):
        return ""
    if "HLA" in str(row["loh_nonfocal"]):
        hlas= row["loh_nonfocal"].split(",")
    elif "HLA" in str(row["loh_focal"]):
        hlas= row["loh_focal"].split(",")
    else:
        hlas= row["loh_hfocal"].split(",")
    l=[]
    for hla in hlas:
        if row["ploidy_major_"+hla] >1:
            l.append(hla)
    return ",".join(l)
    


df["copy_number_neutral_loh_hla"] = df.apply(lambda row: get_copy_number_neutral_loh(row),axis=1)

# %%
df[df["loh_lilac"]==True]["copy_number_neutral_loh_hla"].value_counts()
# Out:
# HLA-A,HLA-C,HLA-B    169
#                      143
# HLA-A                  3
# HLA-C,HLA-B            2
# HLA-A,HLA-B            1
# Name: copy_number_neutral_loh_hla, dtype: int64

# %%
df[(df["loh_lilac"]==True)&(df["loh_nonfocal"].str.contains("HLA",na=False))]["copy_number_neutral_loh_hla"].value_counts()
# Out:
#                      87
# HLA-A,HLA-C,HLA-B    46
# Name: copy_number_neutral_loh_hla, dtype: int64

# %%
46 / (46+87 )
# Out:
# 0.3458646616541353

# %%
df[(df["loh_lilac"]==True)&(df["loh_focal"].str.contains("HLA",na=False))]["copy_number_neutral_loh_hla"].value_counts()
# Out:
# HLA-A,HLA-C,HLA-B    123
#                       56
# HLA-A                  3
# HLA-C,HLA-B            2
# HLA-A,HLA-B            1
# Name: copy_number_neutral_loh_hla, dtype: int64

# %%
(123+3+2+1) / (123+3+2+1+56)
# Out:
# 0.6972972972972973

# %%
df[(df["loh_lilac"]==True)&(df["loh_hfocal"].str.contains("HLA",na=False))]["copy_number_neutral_loh_hla"].value_counts()
# Out:
# HLA-A,HLA-C,HLA-B    24
#                      11
# HLA-A                 3
# HLA-C,HLA-B           2
# HLA-A,HLA-B           1
# Name: copy_number_neutral_loh_hla, dtype: int64

# %%
(24+3+2+1) / (24+3+2+1+11)
# Out:
# 0.7317073170731707

# %% [markdown]
# ### Is it statistically signifcant?

# %%
a=df[(df["loh_lilac"]==True)&(df["loh_focal"].str.contains("HLA",na=False))&(df["copy_number_neutral_loh_hla"].str.contains("HLA",na=False))].shape[0]
b=df[(df["loh_lilac"]==True)&(df["loh_focal"].str.contains("HLA",na=False))&(~df["copy_number_neutral_loh_hla"].str.contains("HLA",na=False))].shape[0]
c=df[(df["loh_lilac"]==True)&(df["loh_nonfocal"].str.contains("HLA",na=False))&(df["copy_number_neutral_loh_hla"].str.contains("HLA",na=False))].shape[0]
d=df[(df["loh_lilac"]==True)&(df["loh_nonfocal"].str.contains("HLA",na=False))&(~df["copy_number_neutral_loh_hla"].str.contains("HLA",na=False))].shape[0]
scipy.stats.fisher_exact([[a,b],[c,d]])
# Out:
# (4.356754658385094, 5.1281638832425e-10)

# %%
a=df[(df["loh_lilac"]==True)&(df["loh_hfocal"].str.contains("HLA",na=False))&(df["copy_number_neutral_loh_hla"].str.contains("HLA",na=False))].shape[0]
b=df[(df["loh_lilac"]==True)&(df["loh_hfocal"].str.contains("HLA",na=False))&(~df["copy_number_neutral_loh_hla"].str.contains("HLA",na=False))].shape[0]
c=df[(df["loh_lilac"]==True)&(df["loh_nonfocal"].str.contains("HLA",na=False))&(df["copy_number_neutral_loh_hla"].str.contains("HLA",na=False))].shape[0]
d=df[(df["loh_lilac"]==True)&(df["loh_nonfocal"].str.contains("HLA",na=False))&(~df["copy_number_neutral_loh_hla"].str.contains("HLA",na=False))].shape[0]
scipy.stats.fisher_exact([[a,b],[c,d]])
# Out:
# (5.158102766798419, 2.275174347112779e-05)

# %%
df.to_csv("../results/data/processed_pcawg_escape_info.tsv.gz",sep="\t",compression="gzip",index=False)

# %%
df.shape
# Out:
# (1880, 153)

# %% [markdown]
# ### Define global prevalence metastatic setting

# %% [markdown]
# ### First read metastatic

# %%
df = pd.read_csv("../results/data/processed_pcawg_escape_info.tsv.gz",sep="\t")

# %% [markdown]
# ### Ratio of metastatic samples

# %%
pallete = {"wt":"#ef8a62","alteration":"#67a9cf","alteration_primary":"#7570b3"}

# %% [markdown]
# ### Load ttypes selected

# %%
ttypes_selected=summary_cohort[summary_cohort["group_PCAWG"]]["cancer_type"].values

# %% [markdown]
# ### Total

# %%
features = ["targeted_app_pathway_mut_HLA","targeted_app_pathway_partdel_HLA","systemic_app_pathway","ifn_gamma_pathway","checkpoint_pathway","cd58_pathway","epigenetic_regulators_pathway","genetic_immune_escape"]
names = ["Somatic mutation HLA","LOH/partial del. HLA","Antigen presentation pathway","IFN-gamma pathway", "PD-L1 amplification","CD58 alteration","Epigenetic regulation by SETDB1","Genetic immune escape \n (GIE)"]

# %% [markdown]
# ### Only ttypes sleected

# %%
tmp=df[["targeted_app_pathway_mut_HLA","targeted_app_pathway_partdel_HLA"]].sum(axis=0)
tmp_norm = (tmp / df.shape[0])

# %% [markdown]
# ### Show variation across tumor types, only tumor types with sufficient representation

# %%
tmp_norm
# Out:
# targeted_app_pathway_mut_HLA        0.019681
# targeted_app_pathway_partdel_HLA    0.169681
# dtype: float64

# %%
fig,ax=plt.subplots(figsize=(8,7))
gs = gridspec.GridSpec(figure=fig, ncols=1, nrows=2, height_ratios=[5,2])
gs.update(hspace=0.05, wspace=0.0)
# distplot
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1],sharex=ax0)
'''
boxplot
'''
a=df[df["cancer_type"].isin(ttypes_selected)].groupby(["cancer_type_code"]).agg(dict([(feature,np.nanmean) for feature in features]+[("sample_id","count")])).reset_index()
a=a[a["sample_id"]>=15]
b=a[features+["cancer_type_code"]].melt(id_vars=["cancer_type_code"])
b=b.merge(a[["cancer_type_code","sample_id"]])
b["size"] = np.log2(b["sample_id"]+1)

g=sns.boxplot(data=b,x="variable",y="value",showfliers=False,color="white",linewidth=1.5,ax=ax0,width=0.6)

sns.stripplot(data=b,x="variable",y="value",alpha=0.75,color=pallete["alteration_primary"],ax=ax0,linewidth=0.5,edgecolor="black",s=8)
ax0.set_ylabel("Proportion of samples \n(cancer type specific)",fontsize=12)
ax0.set_xlabel("")
ax0.spines['top'].set_visible(False)
ax0.spines['right'].set_visible(False)
ax0.set_xticks(range(0,len(features)))
# plot several examples
i=0
for k,v in dict(a[a["sample_id"]>=15].set_index("cancer_type_code").idxmax()).items():
    if k in features and k !="genetic_immune_escape":
        ax0.annotate(xy=(i,a[a["cancer_type_code"]==v][k]),s=v,fontsize=12)
        i+=1
for scode in a["cancer_type_code"].values:
    ax0.annotate(xy=(i,a[a["cancer_type_code"]==scode]["genetic_immune_escape"]),s=scode,fontsize=12)
ax0.set_xticklabels([])
ax0.tick_params(axis='both', which='major', labelsize=12)
ax0.set_ylim(-0.05,0.8)
'''
barplot
'''
tmp = df[features].sum(axis=0)
tmp_norm = (tmp / df.shape[0])
tmp_norm.plot(kind="bar",ylim=(0,0.6),ax=ax1,color=pallete["alteration_primary"],edgecolor="black",width=0.3)
N=df.shape[0]

for i,n in enumerate(tmp_norm.index):
    ax1.annotate(xy=(i-0.15,tmp_norm[i]+0.01),s=int(N*tmp_norm[i]),fontsize=12)
ax1.set_ylabel("Proportion of samples \n (pan-cancer)",fontsize=12)
ax1.set_xticklabels(names,fontsize=12)
ax1.set_ylim(0,0.3)
ax1.tick_params(axis='both', which='major', labelsize=12)


_=ax1.set_xticklabels(names,rotation=90,fontsize=12)

ax1.tick_params(axis='both', which='major', labelsize=12)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

plt.savefig(f'../results/figures/figure2/boxplot_ttype_frequency_selected_pcawg.pdf', dpi=800,bbox_inches="tight")

# %%
a
# Out:
#    cancer_type_code  targeted_app_pathway_mut_HLA  \
# 0              BLCA                      0.043478
# 1              BRCA                      0.000000
# 2              CESC                      0.058824
# 3               CLL                      0.000000
# 4            COREAD                      0.047619
# 5             DLBCL                      0.085106
# 6              ESCA                      0.023810
# 7               GBM                      0.000000
# 8              HNSC                      0.086957
# 9              KICH                      0.000000
# 10             KIRC                      0.010526
# 11             KIRP                      0.000000
# 12             LIHC                      0.010638
# 13              LPS                      0.000000
# 14              MBL                      0.000000
# 15            NSCLC                      0.060241
# 16              ODG                      0.000000
# 17               OS                      0.000000
# 18               OV                      0.000000
# 19             PAAD                      0.019324
# 20            PANET                      0.000000
# 21              PIA                      0.000000
# 22             PRAD                      0.000000
# 23             SKCM                      0.059406
# 24             STAD                      0.037736
# 25             THCA                      0.000000
# 26             UCEC                      0.000000
#
#     targeted_app_pathway_partdel_HLA  systemic_app_pathway  ifn_gamma_pathway  \
# 0                           0.217391              0.000000           0.086957
# 1                           0.111801              0.012422           0.037267
# 2                           0.352941              0.000000           0.058824
# 3                           0.000000              0.000000           0.000000
# 4                           0.166667              0.214286           0.119048
# 5                           0.223404              0.191489           0.021277
# 6                           0.273810              0.000000           0.023810
# 7                           0.030303              0.060606           0.000000
# 8                           0.282609              0.130435           0.086957
# 9                           0.738095              0.000000           0.000000
# 10                          0.115789              0.000000           0.000000
# 11                          0.166667              0.000000           0.000000
# 12                          0.021277              0.042553           0.063830
# 13                          0.187500              0.000000           0.000000
# 14                          0.018868              0.009434           0.009434
# 15                          0.301205              0.048193           0.048193
# 16                          0.055556              0.000000           0.000000
# 17                          0.218750              0.000000           0.000000
# 18                          0.163265              0.000000           0.040816
# 19                          0.280193              0.009662           0.033816
# 20                          0.493506              0.025974           0.000000
# 21                          0.000000              0.000000           0.000000
# 22                          0.006623              0.006623           0.026490
# 23                          0.108911              0.079208           0.059406
# 24                          0.207547              0.075472           0.094340
# 25                          0.000000              0.000000           0.000000
# 26                          0.035714              0.000000           0.000000
#
#     checkpoint_pathway  cd58_pathway  epigenetic_regulators_pathway  \
# 0             0.043478      0.000000                       0.000000
# 1             0.006211      0.000000                       0.049689
# 2             0.000000      0.000000                       0.000000
# 3             0.000000      0.000000                       0.000000
# 4             0.000000      0.000000                       0.000000
# 5             0.000000      0.053191                       0.000000
# 6             0.000000      0.000000                       0.000000
# 7             0.000000      0.000000                       0.000000
# 8             0.043478      0.000000                       0.000000
# 9             0.000000      0.000000                       0.000000
# 10            0.000000      0.000000                       0.000000
# 11            0.000000      0.000000                       0.000000
# 12            0.000000      0.000000                       0.031915
# 13            0.000000      0.000000                       0.000000
# 14            0.000000      0.000000                       0.000000
# 15            0.000000      0.012048                       0.000000
# 16            0.000000      0.000000                       0.000000
# 17            0.000000      0.000000                       0.000000
# 18            0.000000      0.000000                       0.000000
# 19            0.000000      0.004831                       0.004831
# 20            0.000000      0.000000                       0.000000
# 21            0.000000      0.000000                       0.000000
# 22            0.000000      0.000000                       0.000000
# 23            0.009901      0.009901                       0.000000
# 24            0.037736      0.000000                       0.018868
# 25            0.000000      0.000000                       0.000000
# 26            0.000000      0.000000                       0.035714
#
#     genetic_immune_escape  sample_id
# 0                0.347826         23
# 1                0.204969        161
# 2                0.470588         17
# 3                0.000000         60
# 4                0.357143         42
# 5                0.457447         94
# 6                0.309524         84
# 7                0.090909         33
# 8                0.521739         46
# 9                0.738095         42
# 10               0.126316         95
# 11               0.166667         30
# 12               0.170213         94
# 13               0.187500         16
# 14               0.037736        106
# 15               0.397590         83
# 16               0.055556         18
# 17               0.218750         32
# 18               0.204082         49
# 19               0.328502        207
# 20               0.506494         77
# 21               0.000000         42
# 22               0.039735        151
# 23               0.257426        101
# 24               0.358491         53
# 25               0.000000         43
# 26               0.035714         28

# %%
a["genetic_immune_escape"].describe()
# Out:
# count    27.000000
# mean      0.244037
# std       0.191793
# min       0.000000
# 25%       0.073232
# 50%       0.204969
# 75%       0.357817
# max       0.738095
# Name: genetic_immune_escape, dtype: float64

# %%
tmp_norm
# Out:
# targeted_app_pathway_mut_HLA        0.019681
# targeted_app_pathway_partdel_HLA    0.169681
# systemic_app_pathway                0.034574
# ifn_gamma_pathway                   0.031383
# checkpoint_pathway                  0.003723
# cd58_pathway                        0.004255
# epigenetic_regulators_pathway       0.007447
# genetic_immune_escape               0.241489
# dtype: float64

# %%
tmp_norm
# Out:
# targeted_app_pathway_mut_HLA        0.019681
# targeted_app_pathway_partdel_HLA    0.169681
# systemic_app_pathway                0.034574
# ifn_gamma_pathway                   0.031383
# checkpoint_pathway                  0.003723
# cd58_pathway                        0.004255
# epigenetic_regulators_pathway       0.007447
# genetic_immune_escape               0.241489
# dtype: float64

# %%
0.004255*1880
# Out:
# 7.9994000000000005

# %%
a.sort_values("genetic_immune_escape",ascending=False).rename(columns={"sample_id":"n_samples"}).merge(df[["cancer_type_code","cancer_type"]].drop_duplicates()).to_csv("../results/data/summary_gie_cancer_type_pcawg.tsv",sep="\t",index=False)

# %% [markdown]
# ### By tumor type

# %%
def ratio(grp):
    total = len(grp)
    return sum(grp) / total
d_counts_ttype=df.groupby(["cancer_type_code"]).agg({"sample_id":"count"}).to_dict()["sample_id"]

# %% [markdown]
# ### Make status by gene alteration

# %%
cs=['systemic_app_pathway_detail',        'cd58_pathway_detail',        'ifn_gamma_pathway_detail',       'checkpoint_pathway_detail',        'epigenetic_regulators_pathway_detail',       'targeted_app_pathway_mut_HLA', 'targeted_app_pathway_loh_HLA',       'targeted_app_pathway_del_HLA']
l_rs=[]
for c in cs:
    tmp=df[df[c.replace("_detail","")]==True]

    tmp["value"]=True
    tmp=tmp.pivot_table(index=["sample_id","cancer_type_code"],columns=[c],values=["value"],fill_value=False)
    values=[x[1] for x in tmp.columns.values]
    tmp.columns=values
    tmp=tmp.reset_index().groupby("cancer_type_code").agg(dict([(feature,np.nansum) for feature in values]))
    tmp["total_samples"] = tmp.apply(lambda row: d_counts_ttype[row.name],axis=1)
    if not("detail" in c):
        tmp.rename(columns={True:c},inplace=True)
    tmp = tmp.astype(float)
    if not("detail" in c):
        tmpn=pd.DataFrame((tmp[c].div(tmp["total_samples"],axis=0))*100.0,columns=["_".join(c.split("_")[-2:])])
    else:
        tmpn=(tmp[values].div(tmp["total_samples"],axis=0))*100.0
    l_rs.append(tmpn)

stats_gene=pd.concat(l_rs,axis=1).fillna(0.0).reset_index().rename(columns={"index":"cancer_type_code"}).merge(df[["cancer_type_code","cancer_type"]].drop_duplicates())
stats_gene["total_samples"] = stats_gene.apply(lambda row: d_counts_ttype[row.cancer_type_code],axis=1)

# %%
stats_gene
# Out:
#    cancer_type_code   del B2M  del CALR  del NLRC5  del TAPBP    mut B2M  \
# 0              BRCA  0.000000  0.000000   0.000000   0.000000   0.621118
# 1            COREAD  0.000000  0.000000   0.000000   0.000000  11.904762
# 2             DLBCL  1.063830  0.000000   0.000000   0.000000  15.957447
# 3               GBM  0.000000  0.000000   0.000000   0.000000   0.000000
# 4              HNSC  0.000000  0.000000   4.347826   0.000000   6.521739
# 5              LIHC  0.000000  0.000000   0.000000   0.000000   1.063830
# 6               LMS  0.000000  0.000000   0.000000   7.142857   0.000000
# 7               MBL  0.000000  0.000000   0.000000   0.000000   0.000000
# 8             NSCLC  2.409639  0.000000   0.000000   0.000000   0.000000
# 9              PAAD  0.000000  0.000000   0.000000   0.000000   0.000000
# 10            PANET  0.000000  0.000000   0.000000   0.000000   0.000000
# 11             PRAD  0.000000  0.000000   0.000000   0.000000   0.000000
# 12             SKCM  0.990099  1.980198   0.000000   0.000000   1.980198
# 13             STAD  0.000000  0.000000   0.000000   0.000000   3.773585
# 14             BLCA  0.000000  0.000000   0.000000   0.000000   0.000000
# 15             CESC  0.000000  0.000000   0.000000   0.000000   0.000000
# 16             ESCA  0.000000  0.000000   0.000000   0.000000   0.000000
# 17             LAML  0.000000  0.000000   0.000000   0.000000   0.000000
# 18               OV  0.000000  0.000000   0.000000   0.000000   0.000000
# 19             UCEC  0.000000  0.000000   0.000000   0.000000   0.000000
# 20             KIRC  0.000000  0.000000   0.000000   0.000000   0.000000
# 21              BBT  0.000000  0.000000   0.000000   0.000000   0.000000
# 22             CHOL  0.000000  0.000000   0.000000   0.000000   0.000000
# 23             KICH  0.000000  0.000000   0.000000   0.000000   0.000000
# 24             KIRP  0.000000  0.000000   0.000000   0.000000   0.000000
# 25              LPS  0.000000  0.000000   0.000000   0.000000   0.000000
# 26              ODG  0.000000  0.000000   0.000000   0.000000   0.000000
# 27               OS  0.000000  0.000000   0.000000   0.000000   0.000000
# 28             SARC  0.000000  0.000000   0.000000   0.000000   0.000000
#
#     mut CALR  mut CIITA  mut NLRC5  mut RFX5  mut TAP1  mut TAP2  mut TAPBP  \
# 0   0.000000   0.000000   0.621118   0.00000  0.000000  0.000000   0.000000
# 1   0.000000   0.000000   4.761905   0.00000  2.380952  0.000000   2.380952
# 2   0.000000   1.063830   1.063830   0.00000  0.000000  0.000000   0.000000
# 3   0.000000   6.060606   0.000000   0.00000  0.000000  0.000000   0.000000
# 4   0.000000   2.173913   0.000000   0.00000  0.000000  0.000000   0.000000
# 5   0.000000   1.063830   1.063830   1.06383  0.000000  0.000000   0.000000
# 6   0.000000   7.142857   0.000000   0.00000  0.000000  0.000000   0.000000
# 7   0.000000   0.943396   0.000000   0.00000  0.000000  0.000000   0.000000
# 8   0.000000   2.409639   0.000000   0.00000  0.000000  0.000000   0.000000
# 9   0.000000   0.000000   0.483092   0.00000  0.000000  0.483092   0.000000
# 10  1.298701   0.000000   0.000000   0.00000  0.000000  0.000000   1.298701
# 11  0.662252   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 12  0.000000   0.000000   1.980198   0.00000  0.000000  0.990099   0.000000
# 13  0.000000   0.000000   0.000000   0.00000  1.886792  1.886792   0.000000
# 14  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 15  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 16  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 17  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 18  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 19  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 20  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 21  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 22  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 23  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 24  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 25  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 26  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 27  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
# 28  0.000000   0.000000   0.000000   0.00000  0.000000  0.000000   0.000000
#
#     del CD58  mut CD58  del IFNGR2  del IRF2  del JAK1  del JAK2  del STAT1  \
# 0    0.00000  0.000000    0.000000  0.000000  1.863354  1.242236   0.000000
# 1    0.00000  0.000000    2.380952  0.000000  0.000000  0.000000   0.000000
# 2    2.12766  3.191489    0.000000  1.063830  0.000000  0.000000   0.000000
# 3    0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 4    0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 5    0.00000  0.000000    0.000000  4.255319  0.000000  0.000000   0.000000
# 6    0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 7    0.00000  0.000000    0.000000  0.000000  0.000000  0.943396   0.000000
# 8    0.00000  1.204819    0.000000  0.000000  0.000000  1.204819   0.000000
# 9    0.00000  0.483092    0.000000  1.449275  0.000000  0.966184   0.000000
# 10   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 11   0.00000  0.000000    0.000000  0.000000  2.649007  0.000000   0.000000
# 12   0.00000  0.990099    0.990099  0.000000  0.000000  0.990099   0.000000
# 13   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 14   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   4.347826
# 15   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   5.882353
# 16   0.00000  0.000000    0.000000  0.000000  1.190476  0.000000   0.000000
# 17   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 18   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 19   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 20   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 21   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 22   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 23   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 24   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 25   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 26   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 27   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# 28   0.00000  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
#
#     mut APLNR  mut IFNGR2  mut IRF2  mut JAK1   mut JAK2  mut STAT1  \
# 0    0.000000    0.000000  0.000000  0.000000   0.621118   0.000000
# 1    0.000000    0.000000  0.000000  4.761905   4.761905   0.000000
# 2    0.000000    0.000000  0.000000  0.000000   1.063830   0.000000
# 3    0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 4    0.000000    2.173913  0.000000  4.347826   0.000000   2.173913
# 5    0.000000    0.000000  2.127660  0.000000   0.000000   0.000000
# 6    0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 7    0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 8    0.000000    0.000000  1.204819  0.000000   1.204819   1.204819
# 9    0.000000    0.000000  0.000000  0.000000   0.483092   0.483092
# 10   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 11   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 12   0.000000    0.000000  1.980198  0.000000   1.980198   0.000000
# 13   1.886792    0.000000  1.886792  3.773585   1.886792   0.000000
# 14   0.000000    0.000000  0.000000  0.000000   4.347826   0.000000
# 15   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 16   0.000000    0.000000  1.190476  0.000000   0.000000   0.000000
# 17   0.000000    0.000000  0.000000  0.000000  18.181818   0.000000
# 18   0.000000    0.000000  4.081633  0.000000   0.000000   0.000000
# 19   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 20   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 21   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 22   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 23   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 24   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 25   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 26   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 27   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
# 28   0.000000    0.000000  0.000000  0.000000   0.000000   0.000000
#
#     amp CD274  amp SETDB1   mut_HLA    loh_HLA   del_HLA  \
# 0    0.621118    4.968944  0.000000  11.180124  0.621118
# 1    0.000000    0.000000  4.761905  16.666667  0.000000
# 2    0.000000    0.000000  8.510638  22.340426  0.000000
# 3    0.000000    0.000000  0.000000   3.030303  0.000000
# 4    4.347826    0.000000  8.695652  26.086957  2.173913
# 5    0.000000    3.191489  1.063830   2.127660  0.000000
# 6    0.000000    0.000000  0.000000  35.714286  0.000000
# 7    0.000000    0.000000  0.000000   1.886792  0.000000
# 8    0.000000    0.000000  6.024096  30.120482  0.000000
# 9    0.000000    0.483092  1.932367  28.019324  0.000000
# 10   0.000000    0.000000  0.000000  49.350649  0.000000
# 11   0.000000    0.000000  0.000000   0.662252  0.000000
# 12   0.990099    0.000000  5.940594  10.891089  0.000000
# 13   3.773585    1.886792  3.773585  20.754717  0.000000
# 14   4.347826    0.000000  4.347826  21.739130  0.000000
# 15   0.000000    0.000000  5.882353  35.294118  0.000000
# 16   0.000000    0.000000  2.380952  27.380952  0.000000
# 17   0.000000    0.000000  0.000000   0.000000  0.000000
# 18   0.000000    0.000000  0.000000  16.326531  0.000000
# 19   0.000000    3.571429  0.000000   3.571429  0.000000
# 20   0.000000    0.000000  1.052632  11.578947  0.000000
# 21   0.000000    0.000000  0.000000   9.090909  0.000000
# 22   0.000000    0.000000  0.000000  20.000000  0.000000
# 23   0.000000    0.000000  0.000000  73.809524  0.000000
# 24   0.000000    0.000000  0.000000  16.666667  0.000000
# 25   0.000000    0.000000  0.000000  18.750000  0.000000
# 26   0.000000    0.000000  0.000000   5.555556  0.000000
# 27   0.000000    0.000000  0.000000  21.875000  0.000000
# 28   0.000000    0.000000  0.000000  28.571429  0.000000
#
#                        cancer_type  total_samples
# 0                    Breast cancer            161
# 1             Colorectum carcinoma             42
# 2    Diffuse large B-cell lymphoma             94
# 3          Glioblastoma multiforme             33
# 4   Upper respiratory tract cancer             46
# 5         Hepatocellular carcinoma             94
# 6                   Leiomyosarcoma             14
# 7                  Medulloblastoma            106
# 8       Non small cell lung cancer             83
# 9               Pancreas carcinoma            207
# 10         Pancreas neuroendocrine             77
# 11              Prostate carcinoma            151
# 12                   Skin melanoma            101
# 13                  Stomach cancer             53
# 14               Urothelial cancer             23
# 15                Cervix carcinoma             17
# 16                Esophagus cancer             84
# 17          Acute myeloid leukemia             11
# 18                  Ovarian cancer             49
# 19                Uterus carcinoma             28
# 20     Kidney clear cell carcinoma             95
# 21               Bone benign tumor             11
# 22              Cholangiocarcinoma             10
# 23       Kidney chromophobe cancer             42
# 24       Kidney papilary carcinoma             30
# 25                     Liposarcoma             16
# 26               Oligodendroglioma             18
# 27                    Osteosarcoma             32
# 28                 Sarcoma various              7

# %%
stats_gene.to_csv("../results/data/summary_gie_per_gene_cancer_type_pcawg.tsv",sep="\t",index=False)

# %%
ttype_general=df.groupby(["cancer_type"],as_index=False).agg({"epigenetic_regulators_pathway":ratio,"cd58_pathway":ratio,"systemic_app_pathway":ratio,"targeted_app_pathway_mut_HLA":ratio,"targeted_app_pathway_partdel_HLA":ratio,"ifn_gamma_pathway":ratio,"checkpoint_pathway":ratio,"genetic_immune_escape":ratio,"sample_id":"count"}).rename(columns={"sample_id":"n_samples"})
order=list(ttype_general[ttype_general["n_samples"]>=15].sort_values("genetic_immune_escape",ascending=False)["cancer_type"])
ratio_pcawg=ttype_general.sort_values("genetic_immune_escape",ascending=False).set_index("cancer_type")
ratio_pcawg=ratio_pcawg.loc[order]

# %% [markdown]
# ### Going more specific into type of alterations per tumor type

# %%
name_features = {"epigenetic_regulators_pathway":"Epigenetic regulation SETDB1","systemic_app_pathway":"Antigen Presentation Pathway","targeted_app_pathway_mut_HLA":"Mutation HLA genes","targeted_app_pathway_partdel_HLA":"LOH/partial del. HLA","ifn_gamma_pathway": "Alteration Interferon gamma", "checkpoint_pathway":"Checkpoint amplification","cd58_pathway":"CD58 alteration"}
def plot_radar_ttype(values,label,features = features,path_output="results/test.svg",ttype=""):
    # Definition of variables 
    fig,ax = plt.subplots(figsize=(5.,5.))
    fig.suptitle(label,fontsize=18)
    categories=features
    N = len(categories)
    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
    values +=  values[:1]
    # Initialise the spider plot
    ax = plt.subplot(111, polar=True)
    ax.spines['polar'].set_visible(False)
    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    ax.vlines(angles[:-1], 0, [3 for x in range(len(angles[:-1]))], colors="#DCDCDC", zorder=3,linewidth=1.5,alpha=0.5) 
    # Draw ylabels
    ax.set_rlabel_position(0)
    maxv = np.nanmax(values)
    minv = 0.0
    plt.yticks(np.arange(minv,maxv+0.99,0.1), np.arange(minv,maxv+0.99,0.1), color="black", size=10)
    
    ax.plot(angles, values, linewidth=3.5, linestyle='solid', label="Muts",color=pallete["alteration_primary"])
    ax.fill_between(angles, values, linewidth=0.5, linestyle='solid', label="Muts",color=pallete["alteration_primary"],alpha=0.25)
    #ax.grid(b=None,axis="x")
    ax.grid(axis="y",lw=1.25)
    ax.set_yticklabels([ f"{v:.1f}" for v in ax.get_yticks()])
    plt.ylim(minv,maxv+0.1)
    
    # Draw one axe per variable + add labels labels yet
    _=plt.xticks(angles[:-1], [name_features[x]  for x in features],fontsize=12)
    path_output=f"../results/figures/figure2/{ttype.replace(' ','_')}_primary_radar.pdf"
    plt.savefig(path_output,dpi=800,bbox_inches="tight")

# %% [markdown]
# ### What type of alterations per ttype

# %%
ratio_pcawg
# Out:
#                                 epigenetic_regulators_pathway  cd58_pathway  \
# cancer_type
# Kidney chromophobe cancer                            0.000000      0.000000
# Upper respiratory tract cancer                       0.000000      0.000000
# Pancreas neuroendocrine                              0.000000      0.000000
# Cervix carcinoma                                     0.000000      0.000000
# Diffuse large B-cell lymphoma                        0.000000      0.053191
# Non small cell lung cancer                           0.000000      0.012048
# Stomach cancer                                       0.018868      0.000000
# Colorectum carcinoma                                 0.000000      0.000000
# Urothelial cancer                                    0.000000      0.000000
# Pancreas carcinoma                                   0.004831      0.004831
# Esophagus cancer                                     0.000000      0.000000
# Skin melanoma                                        0.000000      0.009901
# Osteosarcoma                                         0.000000      0.000000
# Breast cancer                                        0.049689      0.000000
# Ovarian cancer                                       0.000000      0.000000
# Liposarcoma                                          0.000000      0.000000
# Hepatocellular carcinoma                             0.031915      0.000000
# Kidney papilary carcinoma                            0.000000      0.000000
# Kidney clear cell carcinoma                          0.000000      0.000000
# Glioblastoma multiforme                              0.000000      0.000000
# Oligodendroglioma                                    0.000000      0.000000
# Prostate carcinoma                                   0.000000      0.000000
# Medulloblastoma                                      0.000000      0.000000
# Uterus carcinoma                                     0.035714      0.000000
# Pilocytic astrocytoma                                0.000000      0.000000
# Thyroid cancer                                       0.000000      0.000000
# Chronic lymphocytic leukemia                         0.000000      0.000000
#
#                                 systemic_app_pathway  \
# cancer_type
# Kidney chromophobe cancer                   0.000000
# Upper respiratory tract cancer              0.130435
# Pancreas neuroendocrine                     0.025974
# Cervix carcinoma                            0.000000
# Diffuse large B-cell lymphoma               0.191489
# Non small cell lung cancer                  0.048193
# Stomach cancer                              0.075472
# Colorectum carcinoma                        0.214286
# Urothelial cancer                           0.000000
# Pancreas carcinoma                          0.009662
# Esophagus cancer                            0.000000
# Skin melanoma                               0.079208
# Osteosarcoma                                0.000000
# Breast cancer                               0.012422
# Ovarian cancer                              0.000000
# Liposarcoma                                 0.000000
# Hepatocellular carcinoma                    0.042553
# Kidney papilary carcinoma                   0.000000
# Kidney clear cell carcinoma                 0.000000
# Glioblastoma multiforme                     0.060606
# Oligodendroglioma                           0.000000
# Prostate carcinoma                          0.006623
# Medulloblastoma                             0.009434
# Uterus carcinoma                            0.000000
# Pilocytic astrocytoma                       0.000000
# Thyroid cancer                              0.000000
# Chronic lymphocytic leukemia                0.000000
#
#                                 targeted_app_pathway_mut_HLA  \
# cancer_type
# Kidney chromophobe cancer                           0.000000
# Upper respiratory tract cancer                      0.086957
# Pancreas neuroendocrine                             0.000000
# Cervix carcinoma                                    0.058824
# Diffuse large B-cell lymphoma                       0.085106
# Non small cell lung cancer                          0.060241
# Stomach cancer                                      0.037736
# Colorectum carcinoma                                0.047619
# Urothelial cancer                                   0.043478
# Pancreas carcinoma                                  0.019324
# Esophagus cancer                                    0.023810
# Skin melanoma                                       0.059406
# Osteosarcoma                                        0.000000
# Breast cancer                                       0.000000
# Ovarian cancer                                      0.000000
# Liposarcoma                                         0.000000
# Hepatocellular carcinoma                            0.010638
# Kidney papilary carcinoma                           0.000000
# Kidney clear cell carcinoma                         0.010526
# Glioblastoma multiforme                             0.000000
# Oligodendroglioma                                   0.000000
# Prostate carcinoma                                  0.000000
# Medulloblastoma                                     0.000000
# Uterus carcinoma                                    0.000000
# Pilocytic astrocytoma                               0.000000
# Thyroid cancer                                      0.000000
# Chronic lymphocytic leukemia                        0.000000
#
#                                 targeted_app_pathway_partdel_HLA  \
# cancer_type
# Kidney chromophobe cancer                               0.738095
# Upper respiratory tract cancer                          0.282609
# Pancreas neuroendocrine                                 0.493506
# Cervix carcinoma                                        0.352941
# Diffuse large B-cell lymphoma                           0.223404
# Non small cell lung cancer                              0.301205
# Stomach cancer                                          0.207547
# Colorectum carcinoma                                    0.166667
# Urothelial cancer                                       0.217391
# Pancreas carcinoma                                      0.280193
# Esophagus cancer                                        0.273810
# Skin melanoma                                           0.108911
# Osteosarcoma                                            0.218750
# Breast cancer                                           0.111801
# Ovarian cancer                                          0.163265
# Liposarcoma                                             0.187500
# Hepatocellular carcinoma                                0.021277
# Kidney papilary carcinoma                               0.166667
# Kidney clear cell carcinoma                             0.115789
# Glioblastoma multiforme                                 0.030303
# Oligodendroglioma                                       0.055556
# Prostate carcinoma                                      0.006623
# Medulloblastoma                                         0.018868
# Uterus carcinoma                                        0.035714
# Pilocytic astrocytoma                                   0.000000
# Thyroid cancer                                          0.000000
# Chronic lymphocytic leukemia                            0.000000
#
#                                 ifn_gamma_pathway  checkpoint_pathway  \
# cancer_type
# Kidney chromophobe cancer                0.000000            0.000000
# Upper respiratory tract cancer           0.086957            0.043478
# Pancreas neuroendocrine                  0.000000            0.000000
# Cervix carcinoma                         0.058824            0.000000
# Diffuse large B-cell lymphoma            0.021277            0.000000
# Non small cell lung cancer               0.048193            0.000000
# Stomach cancer                           0.094340            0.037736
# Colorectum carcinoma                     0.119048            0.000000
# Urothelial cancer                        0.086957            0.043478
# Pancreas carcinoma                       0.033816            0.000000
# Esophagus cancer                         0.023810            0.000000
# Skin melanoma                            0.059406            0.009901
# Osteosarcoma                             0.000000            0.000000
# Breast cancer                            0.037267            0.006211
# Ovarian cancer                           0.040816            0.000000
# Liposarcoma                              0.000000            0.000000
# Hepatocellular carcinoma                 0.063830            0.000000
# Kidney papilary carcinoma                0.000000            0.000000
# Kidney clear cell carcinoma              0.000000            0.000000
# Glioblastoma multiforme                  0.000000            0.000000
# Oligodendroglioma                        0.000000            0.000000
# Prostate carcinoma                       0.026490            0.000000
# Medulloblastoma                          0.009434            0.000000
# Uterus carcinoma                         0.000000            0.000000
# Pilocytic astrocytoma                    0.000000            0.000000
# Thyroid cancer                           0.000000            0.000000
# Chronic lymphocytic leukemia             0.000000            0.000000
#
#                                 genetic_immune_escape  n_samples
# cancer_type
# Kidney chromophobe cancer                    0.738095         42
# Upper respiratory tract cancer               0.521739         46
# Pancreas neuroendocrine                      0.506494         77
# Cervix carcinoma                             0.470588         17
# Diffuse large B-cell lymphoma                0.457447         94
# Non small cell lung cancer                   0.397590         83
# Stomach cancer                               0.358491         53
# Colorectum carcinoma                         0.357143         42
# Urothelial cancer                            0.347826         23
# Pancreas carcinoma                           0.328502        207
# Esophagus cancer                             0.309524         84
# Skin melanoma                                0.257426        101
# Osteosarcoma                                 0.218750         32
# Breast cancer                                0.204969        161
# Ovarian cancer                               0.204082         49
# Liposarcoma                                  0.187500         16
# Hepatocellular carcinoma                     0.170213         94
# Kidney papilary carcinoma                    0.166667         30
# Kidney clear cell carcinoma                  0.126316         95
# Glioblastoma multiforme                      0.090909         33
# Oligodendroglioma                            0.055556         18
# Prostate carcinoma                           0.039735        151
# Medulloblastoma                              0.037736        106
# Uterus carcinoma                             0.035714         28
# Pilocytic astrocytoma                        0.000000         42
# Thyroid cancer                               0.000000         43
# Chronic lymphocytic leukemia                 0.000000         60

# %%
for ttype in ratio_pcawg.loc[["Pancreas neuroendocrine","Diffuse large B-cell lymphoma","Colorectum carcinoma","Kidney chromophobe cancer"]].index:
    plot_radar_ttype(list(ratio_pcawg.loc[ttype][features[:-1]].values),features=features[:-1],label=ttype+f" (N={int(ratio_pcawg.loc[ttype]['n_samples'])})",ttype=ttype)

# %% [markdown]
# ## Mutual exclusivity

# %%
import scipy.stats as st

# %%
l=[]
for ttype in order:
    tmp=df[df["cancer_type"]==ttype]
    total=tmp.shape[0]
    a=tmp[(tmp["loh_lilac"]==True)&(tmp["non_targeted_escape"])].shape[0]
    b=tmp[(tmp["loh_lilac"])&(~tmp["non_targeted_escape"])].shape[0]
    if (a+b) < 15:
        continue
    c=tmp[(~tmp["loh_lilac"])&(tmp["non_targeted_escape"])].shape[0]
    d=tmp[(~tmp["loh_lilac"])&(~tmp["non_targeted_escape"])].shape[0]
    o,p=st.fisher_exact([[a,b],[c,d]],alternative="less")
    l.append([ttype,p,o,a,b,c,d])
df_stats_me=pd.DataFrame(l,columns=["cancer_type","pvalue_fisher","odds_ratio","loh_and_other_gie","loh_not_other_gie","not_loh_and_other_gie","not_loh_not_other_gie"]).sort_values("pvalue_fisher")
df_stats_me
# Out:
#                      cancer_type  pvalue_fisher  odds_ratio  \
# 3     Non small cell lung cancer       0.452613    0.633540
# 5               Esophagus cancer       0.524957    0.000000
# 2  Diffuse large B-cell lymphoma       0.701856    1.136842
# 4             Pancreas carcinoma       0.704660    1.106494
# 6                  Breast cancer       0.709215    1.066667
# 1        Pancreas neuroendocrine       0.759740    1.027027
# 0      Kidney chromophobe cancer       1.000000         NaN
#
#    loh_and_other_gie  loh_not_other_gie  not_loh_and_other_gie  \
# 3                  2                 23                      7
# 5                  0                 23                      2
# 2                  6                 15                     19
# 4                  3                 55                      7
# 6                  2                 16                     15
# 1                  1                 37                      1
# 0                  0                 31                      0
#
#    not_loh_not_other_gie
# 3                     51
# 5                     59
# 2                     54
# 4                    142
# 6                    128
# 1                     38
# 0                     11

# %% [markdown]
# ##### Using randomization as methodology

# %% [markdown]
# #####  LOH of HLA-I

# %%
rs=[]
for ttype in order:
    tmp=df[df["cancer_type"]==ttype]
    a=tmp[(tmp["loh_lilac"]==True)&(tmp["non_targeted_escape"])].shape[0]
    b=tmp[(tmp["loh_lilac"])&(~tmp["non_targeted_escape"])].shape[0]
    if (a+b) < 15:
        continue
    
    pa=tmp[tmp["loh_lilac"]].shape[0]/tmp.shape[0]
    pb=tmp[(tmp["non_targeted_escape"])].shape[0]/tmp.shape[0]
    counts=tmp[(tmp["loh_lilac"])&((tmp["non_targeted_escape"]))].shape[0] 
    l_data=[]
    N=10000
    for _ in range(N):
        ma=np.random.binomial(1,p=pa,size=tmp.shape[0])
        mb=np.random.binomial(1,p=pb,size=tmp.shape[0])
        overlap=np.nansum(ma&mb)
        l_data.append(overlap)
    pvalue=np.nansum(counts >= np.array(l_data)) / 10000
    rs.append([ttype,pvalue,counts,np.nanmean(l_data)])
simulated_me=pd.DataFrame(rs,columns=["cancer_type","pvalue_simulations","observed_overlap","expected_mean_overlap"]).sort_values("pvalue_simulations")
simulated_me.merge(df_stats_me)[["cancer_type","loh_and_other_gie","loh_not_other_gie","not_loh_and_other_gie","not_loh_not_other_gie","odds_ratio","pvalue_fisher","expected_mean_overlap","pvalue_simulations"]].to_csv("../results/data/mutual_exclusivity_pcawg.tsv",sep="\t",index=False)
simulated_me.merge(df_stats_me)[["cancer_type","loh_and_other_gie","loh_not_other_gie","not_loh_and_other_gie","not_loh_not_other_gie","odds_ratio","pvalue_fisher","expected_mean_overlap","pvalue_simulations"]]
# Out:
#                      cancer_type  loh_and_other_gie  loh_not_other_gie  \
# 0     Non small cell lung cancer                  2                 23
# 1               Esophagus cancer                  0                 23
# 2  Diffuse large B-cell lymphoma                  6                 15
# 3             Pancreas carcinoma                  3                 55
# 4                  Breast cancer                  2                 16
# 5        Pancreas neuroendocrine                  1                 37
# 6      Kidney chromophobe cancer                  0                 31
#
#    not_loh_and_other_gie  not_loh_not_other_gie  odds_ratio  pvalue_fisher  \
# 0                      7                     51    0.633540       0.452613
# 1                      2                     59    0.000000       0.524957
# 2                     19                     54    1.136842       0.701856
# 3                      7                    142    1.106494       0.704660
# 4                     15                    128    1.066667       0.709215
# 5                      1                     38    1.027027       0.759740
# 6                      0                     11         NaN       1.000000
#
#    expected_mean_overlap  pvalue_simulations
# 0                 2.6978              0.4895
# 1                 0.5513              0.5778
# 2                 5.5753              0.6750
# 3                 2.7956              0.6932
# 4                 1.8913              0.7079
# 5                 0.9801              0.7445
# 6                 0.0000              1.0000

# %%
df[(df["cancer_type_code"]=="DLBCL")&(df["loh_lilac"]==True)&(df["mut_hla_lilac"])]
# Out:
#      sample_id  del_HLA-A  del_HLA-B  del_HLA-C  ploidy_minor_HLA-A  \
# 367    DO52670        0.0        0.0        0.0                   0
# 1790   DO27827        0.0        0.0        0.0                   0
#
#       ploidy_minor_HLA-B  ploidy_minor_HLA-C  ploidy_major_HLA-A  \
# 367                    0                   0                   3
# 1790                   0                   0                   2
#
#       ploidy_major_HLA-B  ploidy_major_HLA-C mut_transport_mhc  \
# 367                    3                   3               NaN
# 1790                   2                   2               NaN
#
#      mut_scaffold_mhc                                           mut_cd58  \
# 367               NaN  CD58;stop_gained;monoallelic;germline_wt;clona...
# 1790              NaN  CD58;frameshift_variant;biallelic;germline_wt;...
#
#      mut_interferon mut_tfs del_transport_mhc del_cd58 del_scaffold_mhc  \
# 367             NaN     NaN               NaN      NaN              NaN
# 1790            NaN     NaN               NaN      NaN              NaN
#
#      del_interferon amps_inhibitors del_tfs epigenetic_regulators  \
# 367             NaN             NaN     NaN                   NaN
# 1790            NaN             NaN     NaN                   NaN
#
#       n_germline_alleles  avg_divergence_germline  sum_diversity_germline  \
# 367                  6.0                12.632781              189.491713
# 1790                 6.0                12.384899              185.773481
#
#       avg_diversity_locus  purity  diploidProportion  wholeGenomeDuplication  \
# 367              8.289134     0.8             0.0000                    True
# 1790             6.327808     0.4             0.0097                    True
#
#      msStatus tmlStatus  tmbPerMb  svTumorMutationalBurden  missense  \
# 367       MSS      HIGH  9.232249                      121       141
# 1790      MSS      HIGH  8.169990                      125       186
#
#       frameshift  mnvs QC_LILAC       A1       A2       B1       B2       C1  \
# 367            8   271     PASS  A*01:01  A*03:01  B*08:01  B*44:02  C*05:01
# 1790          13   323     PASS  A*02:01  A*24:02  B*15:01  B*40:01  C*03:03
#
#            C2  A1_CN  A2_CN  B1_CN  B2_CN  C1_CN  C2_CN  A1_MUT  A2_MUT  \
# 367   C*07:01   2.99   0.01   2.99   0.01   0.01   2.99     0.0     0.0
# 1790  C*03:04   1.99   0.00   0.00   1.99   1.99   0.00     0.0     0.0
#
#       B1_MUT  B2_MUT  C1_MUT  C2_MUT  loh_lilac  mut_hla_lilac  \
# 367      1.0     0.0     0.0     0.0       True           True
# 1790     0.0     1.0     0.0     0.0       True           True
#
#       imbalance_lilac         loh_hfocal          loh_focal loh_nonfocal  \
# 367             False                NaN  HLA-A,HLA-C,HLA-B          NaN
# 1790            False  HLA-A,HLA-C,HLA-B  HLA-A,HLA-C,HLA-B          NaN
#
#      imbalance_hfocal imbalance_focal imbalance_nonfocal  total_fusions  \
# 367               NaN             NaN                NaN             22
# 1790              NaN             NaN                NaN             28
#
#       total_reported_fusions sample_id_2  index cohort patient_id  \
# 367                        0     DO52670   5370  PCAWG    DO52670
# 1790                       1     DO27827   5332  PCAWG    DO27827
#
#                            icgc_aliquot_id icgc_specimen_id icgc_sample_id  \
# 367   929f2216-6ab3-414f-a814-49b69d4b49d9         SP116657       SA542158
# 1790  ce85ccf3-6621-4976-b187-2f28d45dd4d9          SP59400       SA321021
#
#      tissue_type tissue_group                    cancer_type cancer_type_code  \
# 367     Lymphoid     Lymphoid  Diffuse large B-cell lymphoma            DLBCL
# 1790    Lymphoid     Lymphoid  Diffuse large B-cell lymphoma            DLBCL
#
#      blacklist_comment  biopsy_site  simplified_biopsy_site  tumor_purity  \
# 367                NaN          NaN                     NaN           0.8
# 1790               NaN          NaN                     NaN           0.4
#
#       tumor_purity_rank  n_biopsies_in_patient  n_cancer_types_in_patient  \
# 367                 1.0                    1.0                        1.0
# 1790                1.0                    1.0                        1.0
#
#       is_selected_biopsy  ploidy  gender  whole_genome_duplication msi_status  \
# 367                 True     3.8  FEMALE                      True        MSS
# 1790                True     3.4    MALE                      True        MSS
#
#           hr_status had_radiotherapy  had_other_treatment  had_chemotherapy  \
# 367   HR_proficient            False                  NaN               NaN
# 1790  HR_proficient            False                  NaN               NaN
#
#       had_hormone_therapy  had_targeted_therapy  had_immunotherapy  \
# 367                   NaN                   NaN                NaN
# 1790                  NaN                   NaN                NaN
#
#       treatment_info_available  sv_load  smnv_load  sbs_load  dbs_load  \
# 367                        NaN    121.0    26229.0   23081.0     113.0
# 1790                       NaN    125.0    23135.0   20337.0     126.0
#
#       indel_load  sbs_load.clonal  dbs_load.clonal  indel_load.clonal  \
# 367       2987.0          22911.0             86.0             2967.0
# 1790      2622.0          20275.0             71.0             2613.0
#
#       sbs_load.subclonal  dbs_load.subclonal  indel_load.subclonal  \
# 367                127.0                 1.0                   4.0
# 1790                 0.0                 0.0                   0.0
#
#      lilac_status  has_lilac  blacklisted_gie  blacklist_gie_comment  \
# 367          PASS       True            False                    NaN
# 1790         PASS       True            False                    NaN
#
#       is_selected  has_group_cohort  has_group_mut_signatures  has_rna  \
# 367          True              True                      True     True
# 1790         True              True                      True     True
#
#         bcells      cd45       cd8     cytox        dc  exhausted_cd8  \
# 367   4.539669  1.002914 -0.566762  0.814988 -2.276969       0.073980
# 1790  2.449594  2.096730  0.208837 -0.222421 -1.533110       0.745709
#
#        macroph  mast_cells  neutrophil  nk_cd56n        nk    tcells  \
# 367   1.633052   -3.114824   -2.013746 -1.309388 -1.694089 -0.591304
# 1790  2.217933   -2.552488   -1.420240 -0.510082 -1.223980  0.904703
#
#            th1      treg  infiltration_davoli  cd4_davoli  cd8_davoli  \
# 367   0.344828 -2.937357             2.029003   -0.182629    0.564266
# 1790  2.495695 -2.622258             2.782881    1.868097    1.094273
#
#       t_cell_grasso  ifn-gamma  systemic_app_pathway  \
# 367        2.233596   0.978155                 False
# 1790       2.949447   2.475981                 False
#
#      systemic_app_pathway_detail  cd58_pathway cd58_pathway_detail  \
# 367                          NaN          True            mut CD58
# 1790                         NaN          True            mut CD58
#
#       ifn_gamma_pathway ifn_gamma_pathway_detail  checkpoint_pathway  \
# 367               False                      NaN               False
# 1790              False                      NaN               False
#
#      checkpoint_pathway_detail  epigenetic_regulators_pathway  \
# 367                        NaN                          False
# 1790                       NaN                          False
#
#      epigenetic_regulators_pathway_detail  targeted_app_pathway_mut_HLA  \
# 367                                   NaN                          True
# 1790                                  NaN                          True
#
#       targeted_app_pathway_loh_HLA  targeted_app_pathway_del_HLA  \
# 367                           True                         False
# 1790                          True                         False
#
#       targeted_app_pathway_partdel_HLA  targeted_escape  non_targeted_escape  \
# 367                               True             True                 True
# 1790                              True             True                 True
#
#       genetic_immune_escape copy_number_neutral_loh_hla
# 367                    True           HLA-A,HLA-C,HLA-B
# 1790                   True           HLA-A,HLA-C,HLA-B
